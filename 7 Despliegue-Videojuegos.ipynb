# %% [markdown]
# # Despliegue
#
# - Cargamos el modelo
# - Cargamos los datos futuros
# - Preparar los datos futuros
# - Aplicamos el modelo para la predicción

# %%
#Cargamos librerías principales
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Cargamos el modelo
import pickle
filename = 'modelo.pkl'
model_Tree, model_Knn, model_NN, min_max_scaler, variables = pickle.load(open(filename, 'rb'))

# %%
#Cargamos los datos futuros
data = pd.read_csv("videojuegos-despliegue.csv")
data.head()
# Out:
#          videojuego  Edad    Sexo      Plataforma  Consumidor_habitual
# 0     'Mass Effect'    33  Hombre           Otros                False
# 1  'KOA: Reckoning'    30   Mujer              PC                 True
# 2      'Dead Space'    22  Hombre          'Xbox'                False
# 3          'Crysis'    17  Hombre  'Play Station'                False
# 4        'Sim City'    27   Mujer           Otros                 True

# %%
#Se realiza la preparación
data_preparada=data.copy()
data_preparada = pd.get_dummies(data_preparada, columns=['videojuego', 'Plataforma'], drop_first=False)
data_preparada = pd.get_dummies(data_preparada, columns=['Sexo', 'Consumidor_habitual'], drop_first=True)
data_preparada.head()
# Out:
#    Edad  videojuego_'Crysis'  videojuego_'Dead Space'  \
# 0    33                    0                        0
# 1    30                    0                        0
# 2    22                    0                        1
# 3    17                    1                        0
# 4    27                    0                        0
#
#    videojuego_'KOA: Reckoning'  videojuego_'Mass Effect'  \
# 0                            0                         1
# 1                            1                         0
# 2                            0                         0
# 3                            0                         0
# 4                            0                         0
#
#    videojuego_'Sim City'  Plataforma_'Play Station'  Plataforma_'Xbox'  \
# 0                      0                          0                  0
# 1                      0                          0                  0
# 2                      0                          0                  1
# 3                      0                          1                  0
# 4                      1                          0                  0
#
#    Plataforma_Otros  Plataforma_PC  Sexo_Mujer  Consumidor_habitual_True
# 0                 1              0           0                         0
# 1                 0              1           1                         1
# 2                 0              0           0                         0
# 3                 0              0           0                         0
# 4                 1              0           1                         1

# %%
#Se adicionan las columnas faltantes
data_preparada=data_preparada.reindex(columns=variables,fill_value=0)
data_preparada.head()
# Out:
#    Edad  videojuego_'Battlefield'  videojuego_'Crysis'  \
# 0    33                         0                    0
# 1    30                         0                    0
# 2    22                         0                    0
# 3    17                         0                    1
# 4    27                         0                    0
#
#    videojuego_'Dead Space'  videojuego_'F1'  videojuego_'Fifa'  \
# 0                        0                0                  0
# 1                        0                0                  0
# 2                        1                0                  0
# 3                        0                0                  0
# 4                        0                0                  0
#
#    videojuego_'KOA: Reckoning'  videojuego_'Mass Effect'  \
# 0                            0                         1
# 1                            1                         0
# 2                            0                         0
# 3                            0                         0
# 4                            0                         0
#
#    videojuego_'Sim City'  Plataforma_'Play Station'  Plataforma_'Xbox'  \
# 0                      0                          0                  0
# 1                      0                          0                  0
# 2                      0                          0                  1
# 3                      0                          1                  0
# 4                      1                          0                  0
#
#    Plataforma_Otros  Plataforma_PC  Sexo_Mujer  Consumidor_habitual_True
# 0                 1              0           0                         0
# 1                 0              1           1                         1
# 2                 0              0           0                         0
# 3                 0              0           0                         0
# 4                 1              0           1                         1

# %% [markdown]
# # **Predicción con Tree**

# %%
#Hacemos la predicción con el Tree
Y_Tree = model_Tree.predict(data_preparada)
print(Y_Tree)
# Out:
# [ 20. 100. 200. 300. 600.]

# %%
data['Prediccion_Tree']=Y_Tree
data
# Out:
#          videojuego  Edad    Sexo      Plataforma  Consumidor_habitual  \
# 0     'Mass Effect'    33  Hombre           Otros                False
# 1  'KOA: Reckoning'    30   Mujer              PC                 True
# 2      'Dead Space'    22  Hombre          'Xbox'                False
# 3          'Crysis'    17  Hombre  'Play Station'                False
# 4        'Sim City'    27   Mujer           Otros                 True
#
#    Prediccion_Tree
# 0             20.0
# 1            100.0
# 2            200.0
# 3            300.0
# 4            600.0

# %% [markdown]
# # **Prediccion con KNN**

# %%
#Se normaliza la edad para predecir con Knn
data_preparada[['Edad']]= min_max_scaler.transform(data_preparada[['Edad']]) 
data_preparada
# Out:
#        Edad  videojuego_'Battlefield'  videojuego_'Crysis'  \
# 0  0.500000                         0                    0
# 1  0.421053                         0                    0
# 2  0.210526                         0                    0
# 3  0.078947                         0                    1
# 4  0.342105                         0                    0
#
#    videojuego_'Dead Space'  videojuego_'F1'  videojuego_'Fifa'  \
# 0                        0                0                  0
# 1                        0                0                  0
# 2                        1                0                  0
# 3                        0                0                  0
# 4                        0                0                  0
#
#    videojuego_'KOA: Reckoning'  videojuego_'Mass Effect'  \
# 0                            0                         1
# 1                            1                         0
# 2                            0                         0
# 3                            0                         0
# 4                            0                         0
#
#    videojuego_'Sim City'  Plataforma_'Play Station'  Plataforma_'Xbox'  \
# 0                      0                          0                  0
# 1                      0                          0                  0
# 2                      0                          0                  1
# 3                      0                          1                  0
# 4                      1                          0                  0
#
#    Plataforma_Otros  Plataforma_PC  Sexo_Mujer  Consumidor_habitual_True
# 0                 1              0           0                         0
# 1                 0              1           1                         1
# 2                 0              0           0                         0
# 3                 0              0           0                         0
# 4                 1              0           1                         1

# %%
#Hacemos la predicción con Knn
Y_Knn = model_Knn.predict(data_preparada)
data['Prediccion_Knn']=Y_Knn
data
# Out:
#          videojuego  Edad    Sexo      Plataforma  Consumidor_habitual  \
# 0     'Mass Effect'    33  Hombre           Otros                False
# 1  'KOA: Reckoning'    30   Mujer              PC                 True
# 2      'Dead Space'    22  Hombre          'Xbox'                False
# 3          'Crysis'    17  Hombre  'Play Station'                False
# 4        'Sim City'    27   Mujer           Otros                 True
#
#    Prediccion_Tree  Prediccion_Knn
# 0             20.0            20.0
# 1            100.0           100.0
# 2            200.0           200.0
# 3            300.0           300.0
# 4            600.0           600.0

# %% [markdown]
# # **Predicción con NN**

# %%
#Hacemos la predicción con NN
Y_NN = model_NN.predict(data_preparada)
data['Prediccion_NN']=Y_NN
data
# Out:
#          videojuego  Edad    Sexo      Plataforma  Consumidor_habitual  \
# 0     'Mass Effect'    33  Hombre           Otros                False
# 1  'KOA: Reckoning'    30   Mujer              PC                 True
# 2      'Dead Space'    22  Hombre          'Xbox'                False
# 3          'Crysis'    17  Hombre  'Play Station'                False
# 4        'Sim City'    27   Mujer           Otros                 True
#
#    Prediccion_Tree  Prediccion_Knn  Prediccion_NN
# 0             20.0            20.0      19.912913
# 1            100.0           100.0     102.612629
# 2            200.0           200.0     200.320527
# 3            300.0           300.0     299.533717
# 4            600.0           600.0     599.685554
